# %%
import math
from PIL import Image
import requests
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'
import ipywidgets as widgets
from IPython.display import display, clear_output
import torch
from torch import nn
from torchvision.models import resnet50
import torchvision.transforms as T
import cv2
import numpy as np
torch.set_grad_enabled(False);

# %%
model = torch.hub.load('facebookresearch/detr', 'detr_resnet50', pretrained=True)
model.eval();
# Out:
# Using cache found in C:\Users\Dell/.cache\torch\hub\facebookresearch_detr_main

# %%
def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = out_bbox * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    # Convert to (x0, y0, x1, y1) format
    bboxes = torch.cat([b[:, :2] - b[:, 2:] / 2, b[:, :2] + b[:, 2:] / 2], dim=1)
    return bboxes

# %%
COCO_CLASSES = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat',
    'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 
    'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 
    'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 
    'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 
    'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 
    'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'TV', 'laptop', 'mouse', 'remote', 'keyboard', 
    'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 
    'teddy bear', 'hair drier', 'toothbrush'
]

# Transformation to preprocess the input frame
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

def process_frame(frame, model):
    # Convert to PIL image
    pil_img = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    
    # Preprocess image
    img = transform(pil_img).unsqueeze(0)  # Add batch dimension

    # Forward pass through DETR model
    outputs = model(img)

    # Extract bounding boxes, labels, and scores
    probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
    keep = probas.max(-1).values > 0.9  # Filter out low confidence predictions
    bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], pil_img.size)

    # Draw bounding boxes and labels
    draw = ImageDraw.Draw(pil_img)
    for box, label in zip(bboxes_scaled, probas[keep].argmax(-1)):
        x0, y0, x1, y1 = box  # This will now work correctly
        draw.rectangle(((x0, y0), (x1, y1)), outline="red", width=3)
        draw.text((x0, y0), f'{COCO_CLASSES[label]}', fill="red")

    # Convert back to OpenCV format
    return cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)

# %%
def process_video(input_video_path, output_video_path):
    # Capture the input video
    cap = cv2.VideoCapture(input_video_path)
    
    # Get video properties
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))  # Total number of frames
    print(total_frames)
    # Define the codec and create VideoWriter object to save the output video
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))
    
    frame_count = 0  # Initialize frame counter
    
    # Process each frame
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        frame_count += 1  # Update the frame counter

        # Process the frame with DETR
        processed_frame = process_frame(frame, model)

        # Write the processed frame into the output video
        out.write(processed_frame)

        # Print the current frame and total frames
        print(f'Processing frame {frame_count}/{total_frames}')
    
    # Release everything
    cap.release()
    out.release()
    print("Video processing complete!")

# Run the function
input_video = 'E:/Dataset_project/Crop_videos/vid2_27_7_FaisalTown.mp4'  # Path to input video
output_video = 'E:/Dataset_project/Detection/vid2_27_7_FaisalTown.mp4'  # Path to save the processed video
process_video(input_video, output_video)
# Out:
# 416
# Processing frame 1/416
# Processing frame 2/416
# Processing frame 3/416
# Processing frame 4/416
# Processing frame 5/416
# Processing frame 6/416
# Processing frame 7/416
# Processing frame 8/416
# Processing frame 9/416
# Processing frame 10/416
# Processing frame 11/416
# Processing frame 12/416
# Processing frame 13/416
# Processing frame 14/416
# Processing frame 15/416
# Processing frame 16/416
# Processing frame 17/416
# Processing frame 18/416
# Processing frame 19/416
# Processing frame 20/416
# Processing frame 21/416
# Processing frame 22/416
# Processing frame 23/416
# Processing frame 24/416
# Processing frame 25/416
# Processing frame 26/416
# Processing frame 27/416
# Processing frame 28/416
# Processing frame 29/416
# Processing frame 30/416
# Processing frame 31/416
# Processing frame 32/416
# Processing frame 33/416
# Processing frame 34/416
# Processing frame 35/416
# Processing frame 36/416
# Processing frame 37/416
# Processing frame 38/416
# Processing frame 39/416
# Processing frame 40/416
# Processing frame 41/416
# Processing frame 42/416
# Processing frame 43/416
# Processing frame 44/416
# Processing frame 45/416
# Processing frame 46/416
# Processing frame 47/416
# Processing frame 48/416
# Processing frame 49/416
# Processing frame 50/416
# Processing frame 51/416
# Processing frame 52/416
# Processing frame 53/416
# Processing frame 54/416
# Processing frame 55/416
# Processing frame 56/416
# Processing frame 57/416
# Processing frame 58/416
# Processing frame 59/416
# Processing frame 60/416
# Processing frame 61/416
# Processing frame 62/416
# Processing frame 63/416
# Processing frame 64/416
# Processing frame 65/416
# Processing frame 66/416
# Processing frame 67/416
# Processing frame 68/416
# Processing frame 69/416
# Processing frame 70/416
# Processing frame 71/416
# Processing frame 72/416
# Processing frame 73/416
# Processing frame 74/416
# Processing frame 75/416
# Processing frame 76/416
# Processing frame 77/416
# Processing frame 78/416
# Processing frame 79/416
# Processing frame 80/416
# Processing frame 81/416
# Processing frame 82/416
# Processing frame 83/416
# Processing frame 84/416
# Processing frame 85/416
# Processing frame 86/416
# Processing frame 87/416
# Processing frame 88/416
# Processing frame 89/416
# Processing frame 90/416
# Processing frame 91/416
# Processing frame 92/416
# Processing frame 93/416
# Processing frame 94/416
# Processing frame 95/416
# Processing frame 96/416
# Processing frame 97/416
# Processing frame 98/416
# Processing frame 99/416
# Processing frame 100/416
# Processing frame 101/416
# Processing frame 102/416
# Processing frame 103/416
# Processing frame 104/416
# Processing frame 105/416
# Processing frame 106/416
# Processing frame 107/416
# Processing frame 108/416
# Processing frame 109/416
# Processing frame 110/416
# Processing frame 111/416
# Processing frame 112/416
# Processing frame 113/416
# Processing frame 114/416
# Processing frame 115/416
# Processing frame 116/416
# Processing frame 117/416
# Processing frame 118/416
# Processing frame 119/416
# Processing frame 120/416
# Processing frame 121/416
# Processing frame 122/416
# Processing frame 123/416
# Processing frame 124/416
# Processing frame 125/416
# Processing frame 126/416
# Processing frame 127/416
# Processing frame 128/416
# Processing frame 129/416
# Processing frame 130/416
# Processing frame 131/416
# Processing frame 132/416
# Processing frame 133/416
# Processing frame 134/416
# Processing frame 135/416
# Processing frame 136/416
# Processing frame 137/416
# Processing frame 138/416
# Processing frame 139/416
# Processing frame 140/416
# Processing frame 141/416
# Processing frame 142/416
# Processing frame 143/416
# Processing frame 144/416
# Processing frame 145/416
# Processing frame 146/416
# Processing frame 147/416
# Processing frame 148/416
# Processing frame 149/416
# Processing frame 150/416
# Processing frame 151/416
# Processing frame 152/416
# Processing frame 153/416
# Processing frame 154/416
# Processing frame 155/416
# Processing frame 156/416
# Processing frame 157/416
# Processing frame 158/416
# Processing frame 159/416
# Processing frame 160/416
# Processing frame 161/416
# Processing frame 162/416
# Processing frame 163/416
# Processing frame 164/416
# Processing frame 165/416
# Processing frame 166/416
# Processing frame 167/416
# Processing frame 168/416
# Processing frame 169/416
# Processing frame 170/416
# Processing frame 171/416
# Processing frame 172/416
# Processing frame 173/416
# Processing frame 174/416
# Processing frame 175/416
# Processing frame 176/416
# Processing frame 177/416
# Processing frame 178/416
# Processing frame 179/416
# Processing frame 180/416
# Processing frame 181/416
# Processing frame 182/416
# Processing frame 183/416
# Processing frame 184/416
# Processing frame 185/416
# Processing frame 186/416
# Processing frame 187/416
# Processing frame 188/416
# Processing frame 189/416
# Processing frame 190/416
# Processing frame 191/416
# Processing frame 192/416
# Processing frame 193/416
# Processing frame 194/416
# Processing frame 195/416
# Processing frame 196/416
# Processing frame 197/416
# Processing frame 198/416
# Processing frame 199/416
# Processing frame 200/416
# Processing frame 201/416
# Processing frame 202/416
# Processing frame 203/416
# Processing frame 204/416
# Processing frame 205/416
# Processing frame 206/416
# Processing frame 207/416
# Processing frame 208/416
# Processing frame 209/416
# Processing frame 210/416
# Processing frame 211/416
# Processing frame 212/416
# Processing frame 213/416
# Processing frame 214/416
# Processing frame 215/416
# Processing frame 216/416
# Processing frame 217/416
# Processing frame 218/416
# Processing frame 219/416
# Processing frame 220/416
# Processing frame 221/416
# Processing frame 222/416
# Processing frame 223/416
# Processing frame 224/416
# Processing frame 225/416
# Processing frame 226/416
# Processing frame 227/416
# Processing frame 228/416
# Processing frame 229/416
# Processing frame 230/416
# Processing frame 231/416
# Processing frame 232/416
# Processing frame 233/416
# Processing frame 234/416
# Processing frame 235/416
# Processing frame 236/416
# Processing frame 237/416
# Processing frame 238/416
# Processing frame 239/416
# Processing frame 240/416
# Processing frame 241/416
# Processing frame 242/416
# Processing frame 243/416
# Processing frame 244/416
# Processing frame 245/416
# Processing frame 246/416
# Processing frame 247/416
# Processing frame 248/416
# Processing frame 249/416
# Processing frame 250/416
# Processing frame 251/416
# Processing frame 252/416
# Processing frame 253/416
# Processing frame 254/416
# Processing frame 255/416
# Processing frame 256/416
# Processing frame 257/416
# Processing frame 258/416
# Processing frame 259/416
# Processing frame 260/416
# Processing frame 261/416
# Processing frame 262/416
# Processing frame 263/416
# Processing frame 264/416
# Processing frame 265/416
# Processing frame 266/416
# Processing frame 267/416
# Processing frame 268/416
# Processing frame 269/416
# Processing frame 270/416
# Processing frame 271/416
# Processing frame 272/416
# Processing frame 273/416
# Processing frame 274/416
# Processing frame 275/416
# Processing frame 276/416
# Processing frame 277/416
# Processing frame 278/416
# Processing frame 279/416
# Processing frame 280/416
# Processing frame 281/416
# Processing frame 282/416
# Processing frame 283/416
# Processing frame 284/416
# Processing frame 285/416
# Processing frame 286/416
# Processing frame 287/416
# Processing frame 288/416
# Processing frame 289/416
# Processing frame 290/416
# Processing frame 291/416
# Processing frame 292/416
# Processing frame 293/416
# Processing frame 294/416
# Processing frame 295/416
# Processing frame 296/416
# Processing frame 297/416
# Processing frame 298/416
# Processing frame 299/416
# Processing frame 300/416
# Processing frame 301/416
# Processing frame 302/416
# Processing frame 303/416
# Processing frame 304/416
# Processing frame 305/416
# Processing frame 306/416
# Processing frame 307/416
# Processing frame 308/416
# Processing frame 309/416
# Processing frame 310/416
# Processing frame 311/416
# Processing frame 312/416
# Processing frame 313/416
# Processing frame 314/416
# Processing frame 315/416
# Processing frame 316/416
# Processing frame 317/416
# Processing frame 318/416
# Processing frame 319/416
# Processing frame 320/416
# Processing frame 321/416
# Processing frame 322/416
# Processing frame 323/416
# Processing frame 324/416
# Processing frame 325/416
# Processing frame 326/416
# Processing frame 327/416
# Processing frame 328/416
# Processing frame 329/416
# Processing frame 330/416
# Processing frame 331/416
# Processing frame 332/416
# Processing frame 333/416
# Processing frame 334/416
# Processing frame 335/416
# Processing frame 336/416
# Processing frame 337/416
# Processing frame 338/416
# Processing frame 339/416
# Processing frame 340/416
# Processing frame 341/416
# Processing frame 342/416
# Processing frame 343/416
# Processing frame 344/416
# Processing frame 345/416
# Processing frame 346/416
# Processing frame 347/416
# Processing frame 348/416
# Processing frame 349/416
# Processing frame 350/416
# Processing frame 351/416
# Processing frame 352/416
# Processing frame 353/416
# Processing frame 354/416
# Processing frame 355/416
# Processing frame 356/416
# Processing frame 357/416
# Processing frame 358/416
# Processing frame 359/416
# Processing frame 360/416
# Processing frame 361/416
# Processing frame 362/416
# Processing frame 363/416
# Processing frame 364/416
# Processing frame 365/416
# Processing frame 366/416
# Processing frame 367/416
# Processing frame 368/416
# Processing frame 369/416
# Processing frame 370/416
# Processing frame 371/416
# Processing frame 372/416
# Processing frame 373/416
# Processing frame 374/416
# Processing frame 375/416
# Processing frame 376/416
# Processing frame 377/416
# Processing frame 378/416
# Processing frame 379/416
# Processing frame 380/416
# Processing frame 381/416
# Processing frame 382/416
# Processing frame 383/416
# Processing frame 384/416
# Processing frame 385/416
# Processing frame 386/416
# Processing frame 387/416
# Processing frame 388/416
# Processing frame 389/416
# Processing frame 390/416
# Processing frame 391/416
# Processing frame 392/416
# Processing frame 393/416
# Processing frame 394/416
# Processing frame 395/416
# Processing frame 396/416
# Processing frame 397/416
# Processing frame 398/416
# Processing frame 399/416
# Processing frame 400/416
# Processing frame 401/416
# Processing frame 402/416
# Processing frame 403/416
# Processing frame 404/416
# Processing frame 405/416
# Processing frame 406/416
# Processing frame 407/416
# Processing frame 408/416
# Processing frame 409/416
# Processing frame 410/416
# Processing frame 411/416
# Processing frame 412/416
# Processing frame 413/416
# Processing frame 414/416
# Processing frame 415/416
# Processing frame 416/416
# Video processing complete!
